# %% [markdown]
# # Numpy

# %%
import numpy as np

# %%
np1=np.array([1,2,3])
print(np1)
# Out:
# [1 2 3]

# %%
np2=np.array([[1,2,3], [4,5,6]])
print(np2)
print(np2.ndim, np2.shape, np2.dtype)
# Out:
# [[1 2 3]
#  [4 5 6]]
# 2 (2, 3) int32

# %%
np3=np2.reshape((3,2))
print(np3)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
np4=np.eye(3)
print(np4)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
sr1=pd.Series([10,20,30,40])
print(sr1)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# create DataFrame by list
df_list = pd.DataFrame(
[["France", 44, 72000,"No"],
["Spain", 27, 48000, "Yes"],
["Germany", 30, 54000, "No"],
["Spain", 38, 61000, "No"],
["France", 35, 58000, "Yes"],
["Germany", 50, 83000, "No"],
["France", 37, 67000, "Yes"]], columns=["Country", "Age", "Salary", "Purchased"])
print(df_list)
# Out:
#    Country  Age  Salary Purchased
# 0   France   44   72000        No
# 1    Spain   27   48000       Yes
# 2  Germany   30   54000        No
# 3    Spain   38   61000        No
# 4   France   35   58000       Yes
# 5  Germany   50   83000        No
# 6   France   37   67000       Yes

# %%
# creata a DataFrame by dictionary
df_dict = pd.DataFrame({
    "Country":["France", "Spain", "Gremany", "Spain", "France", "France", "Germany", "France"],
    "Age":[44, 27, 30, 38, 35, 48, 50, 37],
    "Salary":[72000, 48000, 54000, 61000, 58000, 79000, 83000, 67000],
    "Purchased":["No", "Yes", "No", "No", "Yes", "Yes", "No", "Yes"]
})
print(df_dict)
# Out:
#    Country  Age  Salary Purchased
# 0   France   44   72000        No
# 1    Spain   27   48000       Yes
# 2  Gremany   30   54000        No
# 3    Spain   38   61000        No
# 4   France   35   58000       Yes
# 5   France   48   79000       Yes
# 6  Germany   50   83000        No
# 7   France   37   67000       Yes

# %% [markdown]
# # Import data

# %%
# if csv as data source
df_reservoir = pd.read_csv("Reservoir.csv")
#df_reservoir.head(5)
# if xlsx as data source & data is in the specific sheet
df_land = pd.read_excel("A_LVR_LAND.xlsx", sheet_name="sheet1")
#df_land.head(5)
# if csv is online
df_born_108 = pd.read_csv("https://data.moi.gov.tw/MoiOD/System/DownloadFile.aspx?DATA=87673B9A-31D7-4900-9D7D-62C715EB54AC")
#df_born_108.head(10)

# %% [markdown]
# if json online is data source
# ![image.png](attachment:image.png)

# %%
import requests
# return object: Response
born_107_data = requests.get("https://od.moi.gov.tw/api/v1/rest/datastore/301000000A-001414-010")
#print(born_107_data, type(born_107_data))

# to check the content
born_107_data.text
# to convert the json as DataFrame (.json() convert data as data type: Dictionary)
df_born_107 = pd.DataFrame(born_107_data.json()['result']['records'])
#df_born_107.head(5)

# %%
# if data is from sk-learn.org
from sklearn import datasets

#loading the Iris datasets
iris=datasets.load_iris()
#iris

#build up a table for flowers' detail data
x=pd.DataFrame(iris['data'], columns=iris['feature_names'])
#build up a table for species' name data
y=pd.DataFrame(iris['target'], columns=['target'])
#merge the two table
iris_data=pd.concat([x,y], axis=1)

# iris_data.info()
# iris_data.head(10)
